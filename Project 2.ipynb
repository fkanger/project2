# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import json
import requests as req
from itertools import groupby

# %%
hmda = pd.read_csv("../Mortgage/hmda_lar.csv")
hmda
# Out:
#     action_taken                            action_taken_name  agency_code  \
# 0              4           Application withdrawn by applicant            2
# 1              4           Application withdrawn by applicant            2
# 2              4           Application withdrawn by applicant            2
# 3              4           Application withdrawn by applicant            2
# 4              4           Application withdrawn by applicant            2
# 5              4           Application withdrawn by applicant            2
# 6              5               File closed for incompleteness            2
# 7              4           Application withdrawn by applicant            2
# 8              4           Application withdrawn by applicant            2
# 9              6            Loan purchased by the institution            2
# 10             5               File closed for incompleteness            2
# ...

# %%
gender= pd.read_csv("hmda_lar.csv")
gender= gender[['applicant_sex_name']].count()
gender
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-3ca4a25c7c7a> in <module>()
# ----> 1 gender= pd.read_csv("hmda_lar.csv")
#       2 gender= gender[['applicant_sex_name']].count()
#       3 gender
#
# ...

# %%
#Male Count
male = gender[gender['applicant_sex_name'] == "Male"].count()
male= male[['applicant_sex_name']]
male
# Out:
# applicant_sex_name    62
# dtype: int64

# %%
#female count
female = gender[gender['applicant_sex_name'] == "Female"].count()
female= female[['applicant_sex_name']]
female
# Out:
# applicant_sex_name    34
# dtype: int64

# %%
#list of all the races in the data
race= pd.read_csv("../Mortgage/hmda_lar.csv")
race= race[['applicant_race_name_1','applicant_ethnicity_name']]
race.count()
race
# Out:
#                                 applicant_race_name_1  \
# 0                                               White
# 1                                               White
# 2   Information not provided by applicant in mail,...
# 3                           Black or African American
# 4                           Black or African American
# 5   Information not provided by applicant in mail,...
# 6                           Black or African American
# 7                           Black or African American
# 8                           Black or African American
# 9                                               White
# 10  Information not provided by applicant in mail,...
# 11                                              White
# 12  Information not provided by applicant in mail,...
# 13                                              White
# 14                                              White
# 15                                              White
# ...

# %%
white = race[race['applicant_race_name_1'] == "White"].count()
white= white[['applicant_race_name_1']]
white
# Out:
# applicant_race_name_1    59
# dtype: int64

# %%
black = race[race['applicant_race_name_1'] == "Black or African American"].count()
black= black[['applicant_race_name_1']]
black
# Out:
# applicant_race_name_1    29
# dtype: int64

# %%
asian = race[race['applicant_race_name_1'] == "Asian"].count()
asian= asian[['applicant_race_name_1']]
asian
# Out:
# applicant_race_name_1    3
# dtype: int64

# %%
hispanic = race[race['applicant_ethnicity_name'] == "Hispanic or Latino"].count()
hispanic= hispanic[['applicant_ethnicity_name']]
hispanic
# Out:
# applicant_ethnicity_name    2
# dtype: int64

# %%
truewhite =
